# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
spiele = pd.read_csv("vg_sales.csv")
spiele.head(10)
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# ...

# %%
spiele_neu = spiele[['Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']]
spiele_neu = spiele_neu.sample(frac=1).reset_index(drop=True)

# %% [markdown]
# ## Data Scientist beim Retro Gamer Magazine
#
# Sie arbeiten als Data Scientist für die Videospiele-Zeitschrift "Retro Gamer Magazine" und sollen helfen Erkenntnisse aus einem Datensatz zu gewinnen. Sie setzen sich an Ihren Arbeitsplatz, schalten den Computer an und nach einiger Zeit landen Sie in einem Ordner, der eine Datei mit dem Namen "vs_sales.csv" beinhaltet. Laden Sie diese Datei in ein Pandas Dataframe und geben Sie die ersten 10 Zeilen aus und schauen Sie sich diese erst mal in Ruhe an.

# %%
spiele_neu.head(10)
# Out:
#                                                 Name Platform    Year  \
# 0  Shin Koihime Musou: Otome Ryouran * Sangokushi...      PSP  2010.0
# 1                             Tribes: Aerial Assault      PS2     NaN
# 2                                Super Mario Bros. 3      GBA  2003.0
# 3                                           NBA 2K11      PS3  2010.0
# 4                            Winx Club: Saving Alfea      3DS  2014.0
# 5                                         The Smurfs       PS  1998.0
# 6                       Future Tactics: The Uprising       XB  2004.0
# 7                       Untold Legends: Dark Kingdom      PS3  2006.0
# 8                                      WWE All Stars      3DS  2011.0
# 9                                        Mario Paint     SNES  1992.0
#
#           Genre             Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0     Adventure                  Yeti      0.00      0.00      0.03
# ...

# %% [markdown]
# Einige Spalten sind selbsterklärend. Bei anderen wissen Sie aber nicht genau was damit gemeint ist. Als erfahrener Data Scientist wissen Sie natürlich was in so einem Fall zu tun ist... Sie fragen einfach nach! Sie holen Ihren Chef zu sich und zeigen ihm mit fragenden Blick nach den Spalten "NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales". Er erklärt ihnen daraufhin, dass es sich jeweils um die Verkaufszahlen in Millionen handelt, entsprechend in Nordamerika, Europa, Japan und dem Rest der Welt. Nun ist alles klar und Sie können anfangen den Datensatz zu analysieren und zu bearbeiten!

# %% [markdown]
# Mögliche Fragen:
# 1. Was sind die beliebtesten Spiele in NA/EU/JP. Gibt es Überschneidungen/Unterschiede? Welche Gründe könnte es dafür geben?
# 2. Zu welchen Genres wurden die meisten/wenigsten Spiele produziert?
# 3. In welchen Jahren wurden die meisten/wenigsten Spiele produziert?
# 4. Welche Publisher produzierte die meisten Spiele?
# 5. Fügen Sie eine weitere Spalte mit dem Namen "Global_Sales" ein, die die Sales aller anderen Spalten aufsummiert.
# 6. Erstellen Sie ein Ranking mit den TOP 20 der meist verkauftesten Spiele mit den Spalten: "Ranking", "Name", "Year", "Genre" und "Publisher".
# 7. Vergleichen Sie die bisherigen Erkenntnisse mit dem was Sie im Internet recherchieren können.
# 8. Überlegen Sie sich weitere Fragen zu dem Datensatz.
# 9. Entfernen Sie alle Zeilen die NaN enthalten und deren Publisher Unknown sind.
#
# Take away:
# - Sortieren
# - Aggregate
# - Datenbereinigung
# - Matplotlib/Seaborn
# - Spalten entfernen/einfügen
# - List Comprehension/zip
